# %% [markdown]
# ## Now You Code 2: Syracuse Crime Data
#
# In this second now you code you will explore the plot.ly engine in detail using Syracuse, NY FBI crime data.

# %%
import plotly.plotly as py    
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/crime/syracuse-crime-data-1985-2012.csv')
crime.sample(10)
# Out:
#     Year  Months  Population  Violent crime total  \
# 4   1989      12      154960                 1360
# 9   1994      12      163374                 1234
# 23  2008      12      138211                 1366
# 21  2006      12      142062                 1515
# 7   1992      12      165029                 1512
# 27  2012      12      145934                 1372
# 10  1995      12      159603                 1467
# 15  2000      12      147306                 1565
# 18  2003      12      145411                 1383
# 16  2001      12      147577                 1562
#
#     Murder and nonnegligent Manslaughter  Forcible rape  Robbery  \
# 4                                     13            113      488
# 9                                     16             58      582
# 23                                    24             71      419
# 21                                    12             66      534
# 7                                     13             85      645
# 27                                    14             75      454
# 10                                    18             84      633
# 15                                    18             47      452
# 18                                    17             44      477
# 16                                    15             42      567
#
#     Aggravated assault  Property crime total  Burglary     ...       \
# 4                  746                 10290      3502     ...
# 9                  578                  9409      2945     ...
# 23                 852                  6165      1938     ...
# 21                 903                  6677      1904     ...
# 7                  769                 10326      3023     ...
# 27                 829                  5976      1896     ...
# 10                 732                  9873      3048     ...
# 15                1048                  7565      1846     ...
# 18                 845                  7773      1975     ...
# 16                 938                  7905      1810     ...
#
#     Violent Crime rate  Murder and nonnegligent manslaughter rate  \
# 4                877.6                                        8.4
# 9                755.3                                        9.8
# 23               988.3                                       17.4
# 21              1066.4                                        8.4
# 7                916.2                                        7.9
# 27               940.2                                        9.6
# 10               919.2                                       11.3
# 15              1062.4                                       12.2
# 18               951.1                                       11.7
# 16              1058.4                                       10.2
#
#     Forcible rape rate  Robbery rate  Aggravated assault rate  \
# 4                 72.9         314.9                    481.4
# 9                 35.5         356.2                    353.8
# 23                51.4         303.2                    616.4
# 21                46.5         375.9                    635.6
# 7                 51.5         390.8                    466.0
# 27                51.4         311.1                    568.1
# 10                52.6         396.6                    458.6
# 15                31.9         306.8                    711.4
# 18                30.3         328.0                    581.1
# 16                28.5         384.2                    635.6
#
#     Property crime rate  Burglary rate  Larceny-theft rate  \
# 4                6640.4         2259.9              4016.5
# 9                5759.2         1802.6              3476.7
# 23               4460.6         1402.2              2695.2
# 21               4700.1         1340.3              2841.7
# 7                6257.1         1831.8              4016.9
# 27               4095.0         1299.2              2534.0
# 10               6186.0         1909.7              3779.4
# 15               5135.6         1253.2              3354.2
# 18               5345.5         1358.2              3171.7
# 16               5356.5         1226.5              3519.5
#
#     Motor vehicle theft rate  Unnamed: 21
# 4                      364.0          NaN
# 9                      479.9          NaN
# 23                     363.2          NaN
# 21                     518.1          NaN
# 7                      408.4          NaN
# 27                     261.8          NaN
# 10                     496.9          NaN
# 15                     528.2          NaN
# 18                     815.6          NaN
# 16                     610.5          NaN
#
# [10 rows x 22 columns]

# %%
# Make a line plot of population over the years, using cufflinks crime.iplot()
# set the titles on x "Year, Y "Population" and cart title " Syracuse Population" 
# TODO: replace the ???? with appropriate values to render the chart
crime.iplot(kind = 'scatter', x = 'Year', y = 'Population', title='Syracuse Population',xTitle='Year',yTitle='Population')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~auramnar/8.embed" height="525px" width="100%"></iframe>

# %%
# Step 1:
# Now plot the same thing using plot.ly without cufflinks, again filling in the templates. Using plot.ly takes more effort but
# you have more control / flexibility over how the plots are rendered.
plot_data = [
    go.Scatter(x=crime['Year'], y=crime['Robbery rate'], mode="lines+markers", name="Robbery Rate", marker=dict(color='orange')),
    go.Scatter(x=crime['Year'], y=crime['Motor vehicle theft rate'], mode="lines+markers", name="Motor Vehicle Theft Rate", marker=dict(color='blue')),
]

py.iplot({ 'data': plot_data,
            'layout': {
               'title': 'Robbery Rate versus Motor Vehicle Theft Rate',
               'xaxis': {
                 'title': 'Year'},
               'yaxis': {
                'title': 'Rate'}
        }})
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~auramnar/10.embed" height="525px" width="100%"></iframe>

# %%
# Step 2:
# Now create a line plot of "Robbery rate" versus "Motor vehicle theft rate" over time.
# NOTE: you will need two series in your plot_data

# %% [markdown]
# # Interactive Plots
#
# Finally write a program to ask for a crime metric like "Robbery" / "Burglary" / "Manslaughter" etc as input,
# then renders a plot of that metric over time as output !
#
# Note: check to make sure the entered crime metric is in the list of Pandas columns before you attempt to plot.
# It might be a good idea to print the column names before you plot.
# if it is not you should print "That is not a crime metric"

# %% [markdown]
# ## Step 3: Problem Analysis
#
# Inputs:
# * filename
# * user input - crimes commited
#
# Outputs:
#
# * graph showing the crime over years
# * input error if crime is not on the list
#
# Algorithm (Steps in Program):
#
# * import statements plotly.ploty, plotly.graph_objs, cufflinks, pandas, and addressing warnings
# * import the csv and assign as variable crime
# * create a list of crimes based on column data.
# * while true to start a loop
#     * user inputs the crime they want to view
#     * if statment for if the user input is in the list of crimes
#         * break to stop the loop and proceed
#     * if statement for if they enter list
#         * count = 1 to start a numbered list
#         * for to start going through each line of the list
#             * print the count and crime to add a displayed list row
#             * increment the count
#             * continue the loop
# * else:
#     * print statment indicating they haven't entered a valid crime
#     * continue the loop
# * assign the plot_data variable to display the graph

# %%
## Step 4: Write code here

## Step 4: Write code here
import plotly.plotly as py    
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

crime = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/crime/syracuse-crime-data-1985-2012.csv')
crime_list = list(crime.columns.values[4:])

while True:
        user_input = input("Enter crime to track or type 'list' crimes list. Type 'quit' to exit: ")
        if user_input in crime_list:
            break
        if user_input == 'list':
            count = 1
            for crime_name in crime_list:
                print("%d: %s" % (count, crime_name))
                count += 1
                continue
        else:
            print("That isn't a valid crime. Try again!")
            continue
plot_data = [
go.Scatter(x=crime['Year'], y=crime[user_input], mode="lines+markers", name=(user_input), marker=dict(color='orange')),
]

py.iplot({ 'data': plot_data,
'layout': {
   'title': ("%s Over Time" % user_input),
   'xaxis': {
     'title': 'Year'},
   'yaxis': {
    'title': user_input}
}})
# Out:
# Enter the crime you'd like to track or type 'list' for a list of crimes. Type 'quit' to exit the program: Robbery
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~auramnar/12.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. What the problem attempted (analysis, code, and answered questions) ?
# 2. What the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
