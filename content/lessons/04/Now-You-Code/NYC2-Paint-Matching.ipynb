# %% [markdown]
# # Now You Code 2: Paint Pricing
#
# House Depot, a big-box hardware retailer, has contracted you to create an app to calculate paint prices.
#
# The price of paint is determined by the following factors:
# - Everyday quality paint is `$19.99` per gallon.
# - Select quality paint is `$24.99` per gallon.
# - Premium quality paint is `$32.99` per gallon.
#
# In addition if the customer wants computerized color-matching that incurs an additional fee of `$4.99` per gallon.
#
# Write a program to ask the user to select a paint quality: 'everyday', 'select' or 'premium' and then whether they need color matching and then outputs the price per gallon of the paint.
#
# Example Run 1:
#
# ```
# Which paint quality do you require ['everyday', 'select', 'premium'] ?select
# Do you require color matching [y/n] ?y
# Total price of select paint with color matching is $29.98
# ```
#
# Example Run 2:
#
# ```
# Which paint quality do you require ['everyday', 'select', 'premium'] ?premium
# Do you require color matching [y/n] ?n
# Total price of premium paint without color matching is $32.99
# ```

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Inputs:
#
# * input paint type (everyday, select or premium)
# * input if color matching service is needed (y or n)
# * gallons of paint needed as a positive integer greater than 0
#
#
# Outputs:
#
# * total cost of paint based on choices (quality, color matching service and gallons needed)
# * error statement to address invalid input (not a paint quality, not y or n, ValueError on the int entry, and not a whole number greater than zero.
#
#
#
# Algorithm (Steps in Program):
#
# * Program Title
# * List option of paint quality
# * Costs as a float for paint quality
# * Input statement for paint quality required
# * Verify entry is within the paint quality list (everyday, select, premium)
# * Input statement requesting paint matching services is needed
# * Statement to handle value errors
# * Input statement requesting number of gallons needed.
# * Statement to address no color matching
# * Statement for when everyday quality is selected
# * Calculation of total cost based on criteria
# * Statement for when select quality is selected
# * Calculation of total cost based on criteria
# * Statement for when premium quality is selected
# * Calculation of total cost based on criteria
# * Total cost based on criteria
# * Statement for when color match is not needed
# * Statement for when everyday quality is selected
# * Calculation of total cost based on criteria
# * Statement for when select quality is selected
# * Calculation of total cost based on criteria
# * Statement for when premium quality is selected
# * Calculation of total cost based on criteria
# * Total cost based on criteria
# * Address error when the user enters a negative number
# * ValueErrors number of gallons statement when non integers are entered.
# * Error statement when y and n is not entered
# * Statement paint quality  input error

# %%
# Step 2: Write code here

#Simple Construction 

everyday = 19.99
select = 24.99
premium = 32.99
color = 4.99
choices = ['Everyday','Select','Premium']
yn = ['Yes','No']

paint = input("Enter your choice of paint: Everyday, Select, or Premium: ")
paint = paint.capitalize()
yeno = input("Do you require color matching? (Yes | No) ")
yeno = yeno.capitalize()

if (paint in choices and yeno in yn):
    print("You chose %s Paint and %s to Color Matching." % (paint,yeno))
    
    if (paint == 'Everyday' and yeno == 'Yes'):
        price = everyday + color
        print("The total price of Everyday paint with color matching is $%.2f per gallon." % (price))
    elif (paint == 'Select' and yeno =='Yes'):
        price = select + color
        print("The total price of Select Quality paint with color matching is $%.2f per gallon." % (price))
    elif (paint == 'Premium' and yeno =='Yes'):
        price = premium + color
        print("The total price of Premium paint with color matching is $%.2f per gallon." % (price))
    elif (paint == 'Everyday' and yeno == 'No'):
        price = everyday
        print("The total price of Everyday paint without color matching is $%.2f per gallon." % (price))
    elif (paint == 'Select' and yeno == 'No'):
        price = select
        print("The total price of Select paint without color matching is $%.2f per gallon." % (price))
    elif (paint == 'Premium' and yeno == 'No'):
        price = premium
        print("The total price of Premium paint without color matching is $%.2f per gallon." % (price))
else: 
    print("ERROR: Paint and Requirment of Color Matching is needed.")
# Out:
# Enter your choice of paint: Everyday, Select, or Premium: Everyday
# Do you require color matching? (Yes | No) YES
# You chose Everyday Paint and Yes to Color Matching.
# The total price of Everyday paint with color matching is $24.98 per gallon.

# %%
# Step 2: Write code here

# Complex construction with descriptors and errors

print("-" * 40)
print("House Depot Paint Calculator")
print("-" * 40)
print("This program will calculate the cost of the paint you'd like to purchase based the type of paint you'd like, the number of gallons you require, and if you would like our premium paint color matching service.")
print("-" * 40)
print("Paint Quality\n\nHouse Depot has three paint qualities available.\n- Everyday quality at $19.99 per gallon\n- Select quality at $24.99 per gallon\n- Premium quality at $32.99 per gallon\n")
print("Color Match Service\n\nHouse Depot also has the ability to match your paint to any color you'd like. The current cost is $4.99 per gallon.")
print("-" * 40)

paint_quality = ['everyday', 'select', 'premium']
paint_match = ['y', 'n']

everyday_paint = float(19.99)
select_paint = float(24.99)
premium_paint = float(32.99)
color_match_service = float(4.99)

user_paint = input("Which type of paint would you like? (Enter everyday, select, or premium): ")
if user_paint in paint_quality:
    user_color_match = input("Would you like to user our color match service? (Enter y or n): ")
    if user_color_match in paint_match:
        try:
            required_paint = int(input("Gallons of paint needed?(Enter number greater than 0): "))  
            if (user_paint in paint_quality and user_color_match == 'y' and required_paint > 0):
                if user_paint == 'everyday' or 'Everyday':
                    total_paint_cost = (everyday_paint + color_match_service) * required_paint
                elif user_paint == 'select' or 'Select':
                    total_paint_cost = (select_paint + color_match_service) * required_paint
                elif user_paint == 'premium' or 'Premium':
                    total_paint_cost = (premium_paint + color_match_service) * required_paint
                print("\nTotal cost for %d paint of %s quality with color match service costs $%.2f." % (required_paint, user_paint, total_paint_cost))
                print("-" * 40)
                print("\nThank you for using House Depot paint calculator. Purchase your paint for $%.2f please visit housedepot.com/paint or visit your nearest store." % total_paint_cost)            
                print("-" * 40)
            elif (user_paint in paint_quality and user_color_match == 'n' and required_paint > 0):
                if user_paint == 'everyday'or 'Everyday':
                    total_paint_cost = everyday_paint * required_paint
                elif user_paint == 'select' or Select:
                    total_paint_cost = select_paint * required_paint
                elif user_paint == 'premium' or 'Premium':
                    total_paint_cost = premium_paint * required_paint
                print("\n Total cost for %d paint of %s quality will cost a total of $%.2f." % (required_paint, user_paint, total_paint_cost))
                print("-" * 40)
                print("\nThank you for using the House Depot paint calculator. Purchase your paint for $%.2f please visit housedepot.com/paint or visit your nearest store." % total_paint_cost)            
                print("-" * 40)
            elif required_paint <= 0:
                print("-" * 40)
                print("Error 10004: Negative Integer Entry. You did not enter a number greater than zero.")
                print("-" * 40)
        except ValueError:
            print("-" * 40)
            print("Error 10001: Invalid Numerical Entry. You didn't enter a number. Please enter a whole number greater than 0.")
            print("-" * 40)
    else:
        print("-" * 40)
        print("Error 10003: Invalid Entry. You must enter 'y' or 'n' for color match service. Entry is case sensitive.")
        print("-" * 40)
else:
    print("-" * 40)
    print("Error 10002: That is not a paint quality. Ensure your paint type is in the form of everyday, select, or premium. Entry is case sensitive.")
    print("-" * 40)
# Out:
# ----------------------------------------
# House Depot Paint Calculator
# ----------------------------------------
# This program will calculate the cost of the paint you'd like to purchase based the type of paint you'd like, the number of gallons you require, and if you would like our premium paint color matching service.
# ----------------------------------------
# Paint Quality
#
# House Depot has three paint qualities available.
# - Everyday quality at $19.99 per gallon
# - Select quality at $24.99 per gallon
# - Premium quality at $32.99 per gallon
#
# Color Match Service
#
# House Depot also has the ability to match your paint to any color you'd like. The current cost is $4.99 per gallon.
# ----------------------------------------
# Which type of paint would you like? (Enter everyday, select, or premium): select
# Would you like to user our color match service? (Enter y or n): n
# Gallons of paint needed?(Enter number greater than 0): 10
#
# ...

# %% [markdown]
# ## Step 3: Questions
#
# 1. When you enter something other than `'everyday', 'select',` or  `'premium'` what happens? Modify the program to print `that is not a paint quality` and then exit in those cases.
# 2. What happens when you enter something other than `'y'` or `'n'` for color matching? Re-write the program to print `you must enter y or n` whenever you enter something other than those two values.
# 3. Why can't we use Python's `try...except` in this example?
# 4. How many times (at minimum) must we execute this program and check the results before we can be reasonably assured it is correct?

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. What the problem attempted (analysis, code, and answered questions) ?
# 2. What the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
